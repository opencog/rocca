# %% [markdown]
# # Hello World MineRL
#
# > A short notebook to test if MineRL runs.

# %%
import gym
import minerl

# %%
env = gym.make('MineRLNavigateDense-v0')

# %%
obs = env.reset()

# %%
env.action_space

# %%
env.observation_space
